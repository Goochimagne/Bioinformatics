# %% [markdown]
# ---
# <div style="text-align: center;">
# <h1>The University of North Carolina at Chapel Hill</h1>
# <h1>Comp 555 BioAlgorithms - Spring 2017</h1>
# <h1 style="font-size: 250%;">Problem Set #4 </h1>
# <h1>Issued Wednesday, 4/13/2017; Due Monday, 4/24/2017</h1>
# </div>
#
# **Homework Information:** Some of the problems are probably too long to be done the night before the due date, so plan accordingly. Late problem sets will be penalized by a factor of	70.71% for each class meeting after the due date. Feel free to get help from others, but the work you submit in should be your own.

# %%
# Replace the following string values with the requested information
class Student:
    first = "Nick"
    last = "Gooch"
    onyen = "nbgooch"
    pid = "720052029"

# %% [markdown]
# ---
# **Problem #1:** Create a suffix array of the [house mouse mitochondrial sequence](http://csbio.unc.edu/mcmillan/Comp555S17/data/MusMusculusMT.fa) used in problem set #3 with the leading '+' replaced by a '&dollar;'. Then find the range suffix-array indices that begin with the "CATTAG" substring.

# %% [raw]
# 6897:6902

# %% [markdown]
# ---
# **Problem #2:** Use the suffix array from problem #1 to construct the BWT of the mouse mitochondria. In this BWT find the longest run of repeated bases. Report both the base and how many times it appears.

# %% [markdown]
# T: 16

# %% [markdown]
# ---
# **Problem #3:** Often it is necessary to search a genomic sequence for a given pattern and its reverse-complement. This can be accomplished using two $O(p)$ queries to the BWT. Suppose instead that we concatenate the given genomic sequence with its reverse-complement with each terminated with a dollar sign and build a BWT of this new string. Will searches in this string find substring in both the given sequence and its reverse complement using just one $O(p)$ query? If not, explain why. If so, decribes any disadvantages of this approach relative to using the original BWR and two queries.

# %% [raw]
# Yes, this will actually work. However by concatenating the reverse complement, we are esentially doubling our search space. Also we must concatenate both the forward pattern and the reverse compliment pattern for searching, so we never actually get 0(p) its actually O(2p).

# %% [markdown]
# **Problem #4: Programming Problem**
#
# Write a function to compute the LCP array of a given BWT string.

# %%
def computeLCP(bwt):
    t = inverseBWT(bwt)
    sa = suffixArray(t)
    N = len(t)
    lcp = [0 for i in xrange(N)]
    for i in xrange(1,N):
        matches = 0
        x = sa[i]
        y = sa[i-1]
        while t[x] == t[y]:
            matches += 1
            x += 1
            y += 1
            if (x >= N) or (y >= N):
                break
        lcp[i] = matches
    return lcp
test = '$banana'
testbwt = BWT(test)
print testbwt
lcp = computeLCP(testbwt)
print lcp
# Out:
# annb$aa
# [0, 0, 1, 3, 0, 0, 2]

# %% [markdown]
# **Problem #5:** Use the function that you wrote for Problem #4 to find the largest k-mer that is repeated more than 250 times in the mouse mitochondria.

# %%
def computeLCP(t, sa):
    N = len(t)
    lcp = [0 for i in xrange(N)]
    for i in xrange(1,N):
        matches = 0
        x = sa[i]
        y = sa[i-1]
        while t[x] == t[y]:
            matches += 1
            x += 1
            y += 1
            if (x >= N) or (y >= N):
                break
        lcp[i] = matches
    return lcp

lcp = computeLCP(txt, sarray)
repeats = []
for i in xrange(len(lcp)-250+1):
    for j in xrange(0,250):
        if lcp[i+j] == 0:
            i = j
            break
    else:
        repeats.append(max([lcp[i] for i in xrange(i, i+250)]))
print len(lcp), len(repeats)
print repeats
# Out:
# 16300 15298
# ...

# %% [raw]
# Enter your k-mer here

# %% [markdown]
# **Helper Methods and Scratch Work**

# %% [markdown]
# **Problem 1:**

# %%
def loadFasta(filename):
    fp = open(filename, 'rb')
    data = fp.read().split('>')
    fp.close
    data.pop(0)
    headers = []
    sequences = []
    for sequence in data:
        lines = sequence.split('\n')
        headers.append(lines.pop(0))
        sequences.append(''.join(lines))
    return (headers, sequences)

def suffixArray(txt):
        return sorted(range(len(txt)), cmp=lambda i,j: 1 if '+' + txt[i:] >= '+' + txt[j:] else -1)
    
def findFirst(pattern, txt, sarray):
    lo, hi = 0, len(txt)
    while(lo < hi):
        mid = (lo + hi) / 2
        if txt[sarray[mid]:] < pattern:
            lo = mid + 1
        else:
            hi = mid
    return lo

def findLast(pattern, txt, sarray):
    lo, hi = 0, len(txt)
    while(lo < hi):
        mid = (lo + hi) / 2
        if txt[sarray[mid]:sarray[mid]+len(pattern)] <= pattern:
            lo = mid + 1
        else:
            hi = mid
    return lo

global txt
head, seq = loadFasta('txt/musMito.fa')
txt = '$'+seq[0]
global sarray
sarray = suffixArray(txt)
substring = "CATTAG" 
first = findFirst(substring, txt, sarray)
last = findLast(substring, txt, sarray)
print '{}:{} {}'.format(first, last, substring)
print 'This means there are 4 elements starting with desired pattern since 6902 is not included'
# Out:
# 6897:6902 CATTAG
# This means there are 4 elements starting with desired pattern since 6902 is not included

# %% [markdown]
# **Problem 2:**

# %%
def SarraytoBWT(txt, sa):
    return ''.join(txt[i-1] for i in sa)

def LCP(txt, sarray):
    m = len(txt)
    lcp = [(0,0) for i in xrange(m)]
    for i in xrange(1,m):
        u = sarray[i-1]
        v = sarray[i]
        n = 0
        while txt[u] == txt[v]:
            n += 1
            u += 1
            v += 1
            if (u >= m-1) or (v >= m-1):
                break
        lcp[i] = (n,txt[v-1])
    return lcp
lcp = LCP(txt, sarray)
print max([i[0] for i in lcp]), i[1]
global bwt
bwt = (txt, sarray)
# Out:
# 16 T

# %% [markdown]
# **Problem 3:**

# %%
forward = "$CATATAG"
rev = "CTATATG$"
cat = forward+rev

def BWT(t):
    rotation = sorted([t[i:]+t[:i] for i in xrange(len(t))])
    return ''.join(r[-1] for r in rotation)

BWT1 = BWT(forward)
BWT2 = BWT(rev)
BWT3 = BWT(cat)

print BWT1
print BWT2
print BWT3
# Out:
# GTTC$AAA
# GTT$TCAA
# G$TTCTT$GTAAACAA

# %% [markdown]
# **Problem 4:**

# %%
def BWT(t):
    rotation = sorted([t[i:]+t[:i] for i in xrange(len(t))])
    return ''.join(r[-1] for r in rotation)

def suffixArray(txt):
    return sorted(range(len(txt)), cmp=lambda i,j: 1 if '+' + txt[i:] >= '+' + txt[j:] else -1)

def inverseBWT(bwt):
    table = ['' for c in bwt]
    for j in xrange(len(bwt)):
        table = sorted([c+table[i] for i, c in enumerate(bwt)])
    return table[bwt.index('$')]

# %% [markdown]
# Click [here to submit](http://csbio.unc.edu/mcmillan/index.py?run=PS.upload) your completed problem set
